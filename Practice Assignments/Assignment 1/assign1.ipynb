# %%
import pandas as pd

# %%
dataset = pd.read_csv('melb_data.csv')

# %%
dataset.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
dataset.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
dataset.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
dataset.shape
# Out:
# (13580, 21)

# %%
dataset.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
dataset.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
cat_data = []
for ele in dataset:
    if dataset[ele].dtypes == 'object':
        cat_data.append(ele)
cat_data
# Out:
# ['Suburb',
#  'Address',
#  'Type',
#  'Method',
#  'SellerG',
#  'Date',
#  'CouncilArea',
#  'Regionname']

# %%
for ele in cat_data:
    print(ele, '->')
    print(dataset[ele].value_counts())
# Out:
# Suburb ->
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Wallan              1
# Plumpton            1
# Emerald             1
# New Gisborne        1
# Croydon South       1
# Name: Suburb, Length: 314, dtype: int64
# Address ->
# 5 Margaret St         3
# 14 Arthur St          3
# 53 William St         3
# 28 Blair St           3
# 36 Aberfeldie St      3
#                      ..
# 125/33 Jeffcott St    1
# 124a Victoria Rd      1
# 12 Tantani St         1
# 202/51 Gordon St      1
# 5 Field St            1
# Name: Address, Length: 13378, dtype: int64
# Type ->
# h    9449
# u    3017
# t    1114
# Name: Type, dtype: int64
# Method ->
# S     9022
# SP    1703
# PI    1564
# VB    1199
# SA      92
# Name: Method, dtype: int64
# SellerG ->
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# ...

# %%
dataset.drop(['Suburb', 'Address', 'SellerG', 'Date', 'CouncilArea'], axis=1, inplace=True)

# %%
dataset
# Out:
#        Rooms Type      Price Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2    h  1480000.0      S       2.5    3067.0       2.0       1.0
# 1          2    h  1035000.0      S       2.5    3067.0       2.0       1.0
# 2          3    h  1465000.0     SP       2.5    3067.0       3.0       2.0
# 3          3    h   850000.0     PI       2.5    3067.0       3.0       2.0
# 4          4    h  1600000.0     VB       2.5    3067.0       3.0       1.0
# ...      ...  ...        ...    ...       ...       ...       ...       ...
# 13575      4    h  1245000.0      S      16.7    3150.0       4.0       2.0
# 13576      3    h  1031000.0     SP       6.8    3016.0       3.0       2.0
# 13577      3    h  1170000.0      S       6.8    3016.0       3.0       2.0
# 13578      4    h  2500000.0     PI       6.8    3016.0       4.0       1.0
# 13579      4    h  1285000.0     SP       6.3    3013.0       4.0       1.0
#
# ...

# %%
pd.get_dummies(dataset)
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  ...  Method_SP  Method_VB  \
# 0         202.0           NaN        NaN  ...          0          0
# ...
